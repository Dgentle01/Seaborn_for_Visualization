# %% [markdown]
# # Python Seaborn for Visualization

# %% [markdown]
# Seaborn was actualy built on top of Matplotib

# %%
import seaborn as sns

# %%
# %matplotlib inline
#allows us to pplot chart within our notebook

# %% [markdown]
# let import a built-in dataset called tips-Note it requires internet connection bfore executing the next cell

# %%
tips = sns.load_dataset('tips')

# %% [markdown]
# # head

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # shape of the data

# %%
tips.shape
# Out:
# (244, 7)

# %% [markdown]
# # to export the data to excel csv

# %%
tips.to_csv("tips.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 tips.to_csv("tips.csv")
#
# NameError: name 'tips' is not defined

# %%
#import that file called tips.csv using pandas
import pandas as pd 
tips_file = pd.read_csv("tips.csv")#enure the file is within the path

tips_file.head()#first 5 rows
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#max of total bill

tips['total_bill'].max()
# Out:
# 50.81

# %%
tips.describe() #summary statistics
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips.info() #information about your data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB

# %% [markdown]
# # if we have missing data

# %%
#data wrongling
#tips.isnull().any()
#or
#tips.isnull().any().any()
#or
#tips.isnull().sum()
#or
#tips.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# # Distplot to visualize the data

# %%
sns.distplot(tips['total_bill'],bins = 50)

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='reg')

# %% [markdown]
# # using seaborn pairplot()

# %%
sns.pairplot(tips, hue='sex', palette='coolwarm')

# %% [markdown]
# # RugPlot

# %%
sns.rugplot(tips['total_bill'])

# %% [markdown]
# # Categorical Plots

# %%
import numpy as np

# %%
sns.barplot(x='sex',y='total_bill', data=tips, estimator=np.std)

# %%
sns.countplot(x='sex', data=tips)

# %% [markdown]
# # Box Plot

# %%
sns.boxplot(x='day', y='total_bill', data=tips)

# %%
sns.boxplot(x='day', y='total_bill', data=tips, hue='sex')

# %%
sns.boxplot(x='day', y='tip', data=tips, hue='sex')

# %%
sns.violinplot(x='day', y='total_bill', data=tips)

# %% [markdown]
# # Stripplot

# %%
#in this case ads JITTER= to see the 'stack point'
sns.stripplot(x='day',y='total_bill', data=tips, jitter=True)

# %% [markdown]
# # lmplot

# %%
sns.lmplot(x='total_bill', y='tip',data=tips)

# %%
sns.lmplot(x='total_bill', y='tip',data=tips, col='sex', row='time')

# %%
iris=sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# # No of unique values we have

# %%
iris['species'].nunique()#no. of unique values we have 
#iris['species'].unique()  #Unique value we have
# Out:
# 3

# %%
sns.pairplot(iris)

# %%
#Facet Grid
g=sns.FacetGrid(data=tips, col='time', row='smoker')
#this has divided the 3 argument up, rows and column are time and smoker,
#and you want to see what is actually being displayed
g.map(sns.distplot,'total_bill')
